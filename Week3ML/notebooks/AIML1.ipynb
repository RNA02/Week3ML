# %% [markdown]
# # Week 3 ML Project
#
# This repository contains my work for the Week 3 machine learning project.
#
# ## Notebooks
#
# - **AIML1.ipynb**
#   Penguins dataset – classification task to predict penguin species.
#
# - **AIML2.ipynb**
#   Titanic dataset – survival prediction (incomplete).
#
# - **AIML3.ipynb**
#   Date Fruit dataset – multi-class classification using numerical features.
#
# - **AIML4.ipynb**
#   Additional dataset (in progress).
#
# - **AIML5.ipynb**
#   Additional dataset (not started).
#
# ## Notes
# - Each notebook follows the standard ML steps: preprocessing, training, and evaluation.
# - Models are saved using joblib.
